# %% [markdown]
# # MatPlotLib

# %%
import numpy as np
x = np.linspace(0, 10, 100)
len(x)
np.sin(x)
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 20)
fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
fig.savefig('my_figure.png')

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x));

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x), "-");

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x), "--");

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x), "o");

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, np.sin(x));

# %%
plt.style.use('seaborn-white')

data = np.random.randn(1000)
plt.hist(data);

# %%
plt.style.use('classic')
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Seno')
ax.plot(x, np.cos(x), '--r', label='Coseno')
ax.axis('equal')
leg = ax.legend();

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
from mpl_toolkits import mplot3d

fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame()

df['x'] = np.random.randn(1000)
df['y'] = np.random.randn(1000)
df.head()
# Out:
#           x         y
# 0  0.720308 -1.300216
# 1 -0.132939  1.158115
# 2 -0.719435  0.728557
# 3  0.807347  0.978251
# 4 -0.184937 -2.710703

# %%
sns.lmplot('x', 'y', data=df, fit_reg=False)

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips);

# %%
figure = sns.catplot(x="day", y="total_bill", kind="bar", hue="sex", data=tips, legend=False)
plt.title("asdas")
plt.legend(loc='upper left', frameon=False)
figure.savefig("check_title.png")

# %%
fig = plt.figure()
ax1 = fig.add_subplot()
ax2 = fig.add_subplot()
sns.catplot(x="day", y="total_bill", kind="box", data=tips, ax=ax1)
sns.catplot(x="day", y="total_bill", kind="bar", hue="sex", data=tips, legend=False, ax=ax2)

# %%
df = pd.DataFrame({'date':['6/2/2017','5/23/2017','5/20/2017','6/22/2017','6/21/2017'],'Revenue':[100,200,300,400,500]})
df.date = pd.to_datetime(df.date)
dg = df.groupby(pd.Grouper(key='date', freq='1M')).sum() # groupby each 1 month
dg.index = dg.index.strftime('%B')
dg
# Out:
#       Revenue
# May       500
# June     1000

# %%
df
# Out:
#         date  Revenue
# 0 2017-06-02      100
# 1 2017-05-23      200
# 2 2017-05-20      300
# 3 2017-06-22      400
# 4 2017-06-21      500

# %%
df["date"]
# Out:
# 0   2017-06-02
# 1   2017-05-23
# 2   2017-05-20
# 3   2017-06-22
# 4   2017-06-21
# Name: date, dtype: datetime64[ns]

# %%
fmri = sns.load_dataset("fmri")
fig = sns.lineplot(
    x="timepoint", 
    y="signal",
    hue="region",
    style='event',
    data=fmri,)
fig.xaxis

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
sns.lineplot(
    x="timepoint", 
    y="signal",
    data=fmri,
    ax=ax1)
sns.lineplot(
    x="timepoint", 
    y="signal",
    style='event',
    data=fmri,
    ax=ax2)
sns.lineplot(
    x="timepoint", 
    y="signal",
    hue="region",
    style='event',
    data=fmri,
    ax=ax3)
# fig.xaxis.set_major_locator(months)

# %%
fmri["subject"].values[-1]
# Out:
# 's0'

# %%
rng = pd.date_range('1/1/2014', periods=20, freq='m')
blah = pd.DataFrame(data = np.random.randn(len(rng)), index=pd.to_datetime(rng))

fig, ax = plt.subplots()

ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%Y'))
ax.bar(blah.index, blah[0], width=25, align='center')
# Out:
# /Users/ma0/miniconda3/envs/curso_rapido_python/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# <BarContainer object of 20 artists>

# %%
rng
# Out:
# DatetimeIndex(['2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30',
#                '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31',
#                '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31',
#                '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31'],
#               dtype='datetime64[ns]', freq='M')
